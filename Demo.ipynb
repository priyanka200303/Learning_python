# %%
print("Jay Jagannath")
# Out:
# Jay Jagannath

# %%
print("I am selected for the internship programe in HAL")
# Out:
# I am selected for the internship programe in HAL

# %%
print("I have sucssesfully passed the interview and the live test")
# Out:
# I have sucssesfully passed the interview and the live test
